# %% [markdown]
# # Natural Sounds Visualizations Tutorial

# %% [markdown]
# Load in the visualization.py functions.

# %%
# %run -i "C:/Users/Vitto/Documents/GitHub/Natural-Sounds-Visualizations/Scripts/visualizations.py

# %% [markdown]
# ## Loading in Sounds as ndarrays
# First, locate the sounds you are interested in visualizing. Edit the file paths respectively. Process them using the following functions.
#
# processing1 and processing2

# %%
path1 = "C:/Users/Vitto/Documents/NSDS/Set A 200 ms Biosounds/c1_e17_u1.crow1_8.h5"

#processing1 will just give me the audio time-series data as an ndarray
processing1(path1)
# Out:
# array([0.15539625, 0.15262254, 0.1485245 , ..., 0.05370919, 0.06220226,
#        0.06952656])

# %%
#if we want the data and sampling rate (for .h5's you must manually find this;
#see visualizations.py's 'Mods' section, works great for .wav's) use processing2
#processing2 works for both .h5 and .wav too
print('Time-series data ndarray:',processing2(path1)[0])
path2 = "C:/Users/Vitto/Downloads/AllSounds/speech_woman1.wav"
print('Sampling Rate (Hz):',processing2(path2)[1])
# Out:
# Time-series data ndarray: [0.15539625 0.15262254 0.1485245  ... 0.05370919 0.06220226 0.06952656]
# Sampling Rate (Hz): 44100

# %% [markdown]
# # Oscillogram
# Now, let's visualize the time-series data of our two sounds. Using
#
# display_oscillogram(sound)

# %%
sound1 = processing2(path1)[0] #Get time-series for the first sound
sound2 = processing2(path2)[0] #Get time-series for the second sound

#Define the sampling_rate (use this name)
sampling_rate = processing2(path2)[1]

display_oscillogram(sound1)
display_oscillogram(sound2)

# %% [markdown]
# # Power Spectral Density (PSD)
# Now, let's visualize the PSD. Change the 'log' inputs between True and False to enable or disable the log-scale (dB) respectively. You can also change the ultrasound threshold itself in the script's Mods.

# %%
# %run -i "C:/Users/Vitto/Documents/GitHub/Natural-Sounds-Visualizations/Scripts/visualizations.py
PSD(sound2)
